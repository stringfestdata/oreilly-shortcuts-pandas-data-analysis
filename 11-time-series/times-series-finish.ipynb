# %%
#! pip install vega_datasets
import pandas as pd
from vega_datasets import local_data
import seaborn as sns
import matplotlib.pyplot as plt

seattle = local_data.seattle_weather()
seattle.head()
# Out:
#         date  precipitation  temp_max  temp_min  wind  weather
# 0 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2 2012-01-03            0.8      11.7       7.2   2.3     rain
# 3 2012-01-04           20.3      12.2       5.6   4.7     rain
# 4 2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='date', y='precipitation', data=seattle)
# Out:
# C:\Users\GeorgeMount\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\GeorgeMount\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='date', ylabel='precipitation'>

# %%
seattle_ts = seattle.set_index('date')
seattle_ts.head()
# Out:
#             precipitation  temp_max  temp_min  wind  weather
# date
# 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2012-01-03            0.8      11.7       7.2   2.3     rain
# 2012-01-04           20.3      12.2       5.6   4.7     rain
# 2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
monthly_precip = seattle_ts.resample('ME').sum()['precipitation']
monthly_precip.head()
# Out:
# date
# 2012-01-31    173.3
# 2012-02-29     92.3
# 2012-03-31    183.0
# 2012-04-30     68.1
# 2012-05-31     52.2
# Freq: ME, Name: precipitation, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x=monthly_precip.index, y=monthly_precip.values)
# Out:
# C:\Users\GeorgeMount\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\GeorgeMount\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='date'>

# %%
seattle['precip_rolling_30'] = seattle['precipitation'].rolling(30).sum()
seattle.head(60)
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather  \
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain
# 5  2012-01-06            2.5       4.4       2.2   2.2     rain
# 6  2012-01-07            0.0       7.2       2.8   2.3     rain
# 7  2012-01-08            0.0      10.0       2.8   2.0      sun
# 8  2012-01-09            4.3       9.4       5.0   3.4     rain
# 9  2012-01-10            1.0       6.1       0.6   3.4     rain
# 10 2012-01-11            0.0       6.1      -1.1   5.1      sun
# 11 2012-01-12            0.0       6.1      -1.7   1.9      sun
# 12 2012-01-13            0.0       5.0      -2.8   1.3      sun
# 13 2012-01-14            4.1       4.4       0.6   5.3     snow
# ...

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=seattle, x='date', y='precip_rolling_30')
# Out:
# C:\Users\GeorgeMount\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\GeorgeMount\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='date', ylabel='precip_rolling_30'>

# %%
seattle['precip_lead'] = seattle['precipitation'].shift(-1)
seattle['precip_lag'] = seattle['precipitation'].shift(1)
seattle.head()
# Out:
#         date  precipitation  temp_max  temp_min  wind  weather  \
# 0 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2 2012-01-03            0.8      11.7       7.2   2.3     rain
# 3 2012-01-04           20.3      12.2       5.6   4.7     rain
# 4 2012-01-05            1.3       8.9       2.8   6.1     rain
#
#    precip_rolling_30  precip_lead  precip_lag
# 0                NaN         10.9         NaN
# 1                NaN          0.8         0.0
# 2                NaN         20.3        10.9
# 3                NaN          1.3         0.8
# 4                NaN          2.5        20.3

# %%
seattle.tail()
# Out:
#            date  precipitation  temp_max  temp_min  wind weather  \
# 1456 2015-12-27            8.6       4.4       1.7   2.9     fog
# 1457 2015-12-28            1.5       5.0       1.7   1.3     fog
# 1458 2015-12-29            0.0       7.2       0.6   2.6     fog
# 1459 2015-12-30            0.0       5.6      -1.0   3.4     sun
# 1460 2015-12-31            0.0       5.6      -2.1   3.5     sun
#
#       precip_rolling_30  precip_lead  precip_lag
# 1456              283.5          1.5         0.0
# 1457              285.0          0.0         8.6
# 1458              285.0          0.0         1.5
# 1459              284.5          0.0         0.0
# 1460              272.3          NaN         0.0
